# %%
from langchain_ollama import ChatOllama

# %%
llm = ChatOllama(model="gemma3:1b")

# %%
res = llm.invoke("Hello, I am Prateek")
res.content
# Out:
# "Hello Prateek! It's nice to meet you. How can I help you today? 😊 \n\nIs there anything you'd like to talk about, or perhaps you need some assistance with something?"
