# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
from langchain_groq import ChatGroq
from langchain_openai import ChatOpenAI

# %%
llm = ChatGroq(model="openai/gpt-oss-20b")
openaiLLm = ChatOpenAI(model="gpt-5")

# %%
res = llm.invoke("Can you explain me GEN-AI ?")
print(res.content)
# Out:
# ### What is “Gen‑AI” (Generative AI)?
#
# **Generative AI** is a branch of artificial intelligence that learns to *create* new content—text, images, audio, video, code, and more—rather than simply *classifying* or *predicting* existing data. Think of it as a digital artist, writer, or composer that has read (or seen) thousands of examples and can now produce something that looks like it came from the same creative domain.
#
# ---
#
# ## 1. Core Idea
#
# | Traditional AI (Discriminative) | Generative AI |
# |----------------------------------|---------------|
# | Trained to **recognize** patterns: e.g., classify emails as spam or not spam. | Trained to **generate** new data that follows the same statistical patterns. |
# | Learns a mapping from input → label. | Learns a probability distribution \(P(\text{data})\). |
# | Uses supervised or reinforcement learning. | Often uses unsupervised or self‑supervised learning. |
# | Example models: SVM, Random Forest, CNN for image classification. | Example models: GPT‑4, DALL‑E, Stable Diffusion, Midjourney, Midjourney‑style. |
#
# ---
#
# ## 2. How It Works
#
# 1. **Data Collection**
#    - Gather a large corpus of the target content (e.g., millions of text documents, images, or audio files).
#    - The data must be representative of the style, domain, and quality you want the model to learn.
#
# 2. **Model Architecture**
#    - **Transformers** (e.g., GPT, BERT, T5) dominate text generation.
#    - **Diffusion Models** (e.g., Stable Diffusion, Imagen) dominate image generation.
#    - **GANs** (Generative Adversarial Networks) were early pioneers for images.
#    - **VQ‑VAE** and **Flow‑Based Models** are alternatives.
#
# 3. **Training Objective**
#    - **Autoregressive**: Predict the next token/word/pixel given the past.
#    - **Diffusion**: Learn to denoise from random noise to a clean image.
#    - **GAN**: Minimize a game between a generator and a discriminator.
#    - **Variational Autoencoders**: Encode data into a latent space and decode.
#
# 4. **Learning the Distribution**
#    - The model approximates the true distribution \(P(\text{data})\).
#    - After training, sampling from this distribution yields *novel* content that looks like it could have come from the training set.
#
# 5. **Inference / Generation**
#    - **Prompt‑based**: Provide a seed text or image; the model continues or completes it.
#    - **Sampling Strategies**: Greedy, beam search, temperature scaling, top‑k/top‑p (nucleus) sampling.
#
# ---
#
# ## 3. Representative Models & Their Domains
#
# | Domain | Model | Key Features |
# |--------|-------|--------------|
# | **Text** | GPT‑4, Claude, LLaMA | Large‑scale transformer, few‑shot learning, fine‑tuned for specific tasks. |
# | **Image** | DALL‑E 2, Stable Diffusion, Midjourney | Diffusion models that map text prompts to images. |
# | **Audio** | Jukebox, WaveNet, AudioLM | Generates music or speech conditioned on prompts or prior audio. |
# | **Video** | Make‑It‑Real, VideoGPT | Generates short video clips from text or image prompts. |
# | **Code** | Codex, AlphaCode | Generates code snippets from natural language descriptions. |
#
# ---
#
# ## 4. Common Applications
#
# | Category | Use Cases |
# |----------|-----------|
# | **Creative Arts** | Writing stories, poems, song lyrics; generating artwork, concept art, or video game assets. |
# | **Productivity** | Drafting emails, summarizing documents, auto‑completing code, generating meeting minutes. |
# | **Design** | UI/UX mockups, 3D models, architectural sketches. |
# | **Marketing** | Personalized ads, copywriting, social media posts. |
# | **Education** | Adaptive tutoring, generating practice problems, explanatory content. |
# | **Healthcare** | Synthesizing medical images for training, generating patient notes. |
# | **Entertainment** | Story generation, dialogue for NPCs, procedural game content. |
#
# ---
#
# ## 5. Advantages
#
# - **Speed & Scale**: Create thousands of unique assets in seconds.
# - **Cost‑Effectiveness**: Reduces the need for large creative teams.
# - **Personalization**: Tailor content to individual preferences or brand voice.
# - **Accessibility**: Lowers barriers for non‑experts to produce professional‑looking material.
#
# ---
#
# ## 6. Challenges & Risks
#
# | Issue | Description |
# |-------|-------------|
# | **Quality Control** | Generated content can be inconsistent or nonsensical. |
# | **Hallucinations** | AI may produce facts that are false or misleading. |
# | **Bias & Fairness** | Models can amplify biases present in training data. |
# | **Copyright & Ownership** | Ambiguity around who owns AI‑generated content. |
# | **Misuse** | Deepfakes, fake news, plagiarism, or malicious code generation. |
# | **Compute & Energy** | Training large models consumes significant resources. |
# | **Ethical & Societal Impact** | Job displacement, creative authenticity, cultural appropriation. |
#
# ---
#
# ## 7. Key Concepts in Generative AI
#
# | Concept | What It Means |
# |---------|---------------|
# | **Latent Space** | A compressed representation where similar inputs cluster together. |
# | **Fine‑Tuning** | Adapting a pre‑trained model to a specific domain or style. |
# | **Prompt Engineering** | Crafting input prompts to steer the model toward desired outputs. |
# | **Diffusion Process** | Iteratively refining random noise into a coherent image or audio. |
# | **Self‑Supervised Learning** | Learning from the data itself (e.g., predicting missing words). |
# | **Zero‑Shot / Few‑Shot Learning** | Performing a task with no or minimal task‑specific training. |
#
# ---
#
# ## 8. A Quick “How‑to” Example (Text)
#
# 1. **Choose a Model**: e.g., GPT‑4 via OpenAI’s API.
# 2. **Set the Prompt**: `"Write a short story about a robot learning to paint."`
# 3. **Adjust Parameters**: Temperature 0.7, max tokens 300.
# 4. **Run**: Send the request, receive the generated text.
# 5. **Post‑Process**: Edit, fact‑check, or feed back into the model for refinement.
#
# ---
#
# ## 9. Future Outlook
#
# - **Multimodal Models**: Combine text, image, audio, and video in a single architecture (e.g., GPT‑4V).
# - **More Efficient Training**: Techniques like sparsity, quantization, and distillation to reduce compute costs.
# - **Better Alignment & Safety**: Human‑in‑the‑loop training, reinforcement learning from human feedback (RLHF), and safety layers.
# - **Domain‑Specific Models**: Tailored models for medicine, law, engineering, etc., with stricter compliance.
# - **Regulation & Standards**: Governments and industry groups working on guidelines for AI‑generated content.
#
# ---
#
# ## 10. Bottom Line
#
# Generative AI is **not** a single technology but a set of powerful learning frameworks that can *imagine* new content. Whether you’re a writer, designer, developer, or business owner, understanding Gen‑AI opens doors to unprecedented creativity, efficiency, and innovation—while also demanding careful attention to ethics, quality, and responsible use.
