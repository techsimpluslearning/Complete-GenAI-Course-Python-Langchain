# %%
from langchain_openai import ChatOpenAI

# %%
llm = ChatOpenAI(model="gpt-4o")

# %%
prompts = [
    {"role":"system", "content":"You are a JavaScript Developer ?"},
    {"role":"user", "content":"Difference b/w map and filter ?"},
]

res = llm.invoke(prompts)
print(res.content)
# Out:
# In JavaScript, both `map` and `filter` are array methods that iterate over the elements of an array, but they serve different purposes and have distinct behaviors.
#
# ### `map` Method:
# - **Purpose**: The `map` method creates a new array by applying a provided function to each element of the original array.
# - **Returns**: A new array with the transformed elements.
# - **Number of elements**: The new array has the same number of elements as the original array because `map` applies the function to every element.
# - **Example**:
#   ```javascript
#   const numbers = [1, 2, 3, 4, 5];
#   const doubled = numbers.map(number => number * 2);
#   console.log(doubled); // Output: [2, 4, 6, 8, 10]
#   ```
#   In this example, each number in the array is doubled, and a new array with these doubled values is returned.
#
# ### `filter` Method:
# - **Purpose**: The `filter` method creates a new array with all elements that pass a test implemented by the provided function.
# - **Returns**: A new array with only the elements that satisfy the condition specified in the function.
# - **Number of elements**: The size of the new array can be less than or equal to the original array because only the elements that pass the test are included.
# - **Example**:
#   ```javascript
#   const numbers = [1, 2, 3, 4, 5];
#   const evenNumbers = numbers.filter(number => number % 2 === 0);
#   console.log(evenNumbers); // Output: [2, 4]
#   ```
#   Here, only the even numbers from the original array are included in the new array.
#
# ### Summary:
# - Use `map` when you want to transform all elements in the array and get a new array with the same number of elements.
# - Use `filter` when you want to select a subset of elements from the array based on a condition, resulting in a new array that may have fewer elements.

# %%
prompts = [
    {"role":"system", "content":"You are a Python Developer ?"},
    {"role":"user", "content":"Difference b/w map and filter ?"},
]

res = llm.invoke(prompts)
print(res.content)
# Out:
# Both `map` and `filter` are built-in Python functions used for processing iterables, but they serve different purposes and operate in distinct ways:
#
# ### `map`
#
# - **Purpose**: `map` applies a given function to each item of an iterable (like a list) and returns an iterator (or a `map` object in Python 3) that yields the transformed items.
# - **Use Case**: When you need to perform a transformation or operation on each element of the iterable.
# - **Example**:
#   ```python
#   def square(x):
#       return x * x
#
#   numbers = [1, 2, 3, 4]
#   squared_numbers = map(square, numbers)  # returns a map object
#   print(list(squared_numbers))  # Output: [1, 4, 9, 16]
#   ```
#
# ### `filter`
#
# - **Purpose**: `filter` applies a given function to each item of an iterable and returns an iterator (or a `filter` object in Python 3) containing only the items for which the function returns `True`.
# - **Use Case**: When you need to select a subset of elements from an iterable based on some condition.
# - **Example**:
#   ```python
#   def is_even(x):
#       return x % 2 == 0
#
#   numbers = [1, 2, 3, 4]
#   even_numbers = filter(is_even, numbers)  # returns a filter object
#   print(list(even_numbers))  # Output: [2, 4]
#   ```
#
# ### Key Differences
#
# - **Function Behavior**: `map` transforms elements, while `filter` selects elements.
# - **Return**: Both return an iterator, but `map` returns an iterator of transformed elements, whereas `filter` returns an iterator of the elements that satisfy a condition.
# - **Function Requirement**: The function used with `map` can return any type, whereas the function used with `filter` must return a Boolean value (`True` or `False`).
#
# Both `map` and `filter` can be very handy for concise and functional-style programming in Python.

# %%
prompts = [
    {"role":"system", "content":"You are a translator and translate input in Hindi ?"},
    {"role":"user", "content":"I love to play Cricket ?"},
]

res = llm.invoke(prompts)
print(res.content)
# Out:
# मैं क्रिकेट खेलना पसंद करता हूँ।

# %% [markdown]
# #### Prompt Templates - Dynamic Prompts

# %%
from langchain_openai import ChatOpenAI
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.output_parsers import StrOutputParser

# %%
llm = ChatOpenAI(model="gpt-4o")
out = StrOutputParser()

# %%
#### My Self Chain Node

def transform_case(result:str):
    return result.upper()

# %%
prompts = ChatPromptTemplate.from_messages([
    {"role":"system", "content":"You are a translator and translate input in {language} ?"},
    {"role":"user",  "content":"{query}"},
])

# %%
# final_prompts = prompts.format_messages(language = "Hinglish ?", 
#                                         query = "I love Python, and JavaScript ?")
# res = llm.invoke(final_prompts)
# print(res.content)

# %%
# res = llm.invoke(prompts.invoke({"language":"Hindi", "query":"I love You ?"}))
# res.content

# %%
chains = prompts | llm | out | transform_case

# %%
res = chains.invoke({"language":"Hinglish", "query":"I love LangChain ?"})
print(res)
# Out:
# MAIN LANGCHAIN PASAND KARTA HOON.
