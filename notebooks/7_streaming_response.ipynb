# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
from langchain_openai import ChatOpenAI

# %%
llm = ChatOpenAI(model="gpt-4", streaming=True)

# %%
question = "Can you explain me GEN-AI ?"

# %%
response = llm.stream(question)
for chunk in response:
    print(chunk.content, end="")
# Out:
# GEN-AI is a term that stands for General Artificial Intelligence. This refers to the concept of creating artificial intelligence that can perform any intellectual task that a human being can do. This includes understanding, learning, adapting and implementing knowledge and skills in a wide range of situations which they weren't specifically programmed for. Currently, this is a largely theoretical concept, as most existing AI are specialized and designed to perform specific tasks. The development of GEN-AI represents a significant ambition in the field of artificial intelligence research.

# %%
from langchain_groq import ChatGroq

# %%
llm = ChatGroq(model="openai/gpt-oss-20b", streaming=True)

# %%
question = "Can you explain me GEN-AI ?"
response = llm.stream(question)
for chunk in response:
    print(chunk.content, end="")
# Out:
# ## What is GEN‑AI?
# **GEN‑AI** is short for **Generative Artificial Intelligence** – a class of AI systems that can *create* new content instead of just recognizing patterns or making predictions. Think of it as a digital “artist” or “writer” that learns from a huge amount of existing data and then produces something that looks, sounds, or behaves like that data—but is brand‑new.
#
# ---
#
# ### 1. How Generative AI Works (in a nutshell)
#
# | Step | What Happens | Key Technology |
# |------|--------------|----------------|
# | **1. Data Collection** | Gather massive datasets (text, images, audio, etc.). | Web scrapers, public datasets, user‑generated content. |
# | **2. Training** | Feed the data into a neural network that learns statistical patterns. | Deep learning architectures – Transformers for text, Diffusion models for images, etc. |
# | **3. Generation** | The trained model produces new samples by sampling from the learned distribution. | Sampling tricks (temperature, top‑k, nucleus sampling). |
# | **4. Fine‑tuning / Prompting** | Adjust the model to be more useful or safer. | Reinforcement Learning from Human Feedback (RLHF), instruction‑tuning. |
#
# ---
#
# ### 2. Popular Generative Models
#
# | Domain | Model | What It Generates | Key Papers |
# |--------|-------|-------------------|------------|
# | **Text** | GPT‑4, GPT‑3, LLaMA, Claude | Natural‑language text, code, dialogue | “Attention Is All You Need” (2017), “ChatGPT” (2022) |
# | **Images** | DALL‑E 2, Stable Diffusion, Midjourney | Photorealistic or stylized images from text prompts | “DALL‑E: Creating Images from Text” (2021), “Diffusion Models Beat GANs” (2022) |
# | **Audio** | WaveNet, Jukebox, AudioLM | Speech, music, sound effects | “WaveNet: Generative Models for Raw Audio” (2016) |
# | **Video** | VideoGPT, Phenaki, Make‑It‑Real | Short video clips, animations | “VideoGPT: Learning Video Representations from Self‑Supervised Transformers” (2023) |
# | **Multimodal** | CLIP‑GPT, Flamingo, Gemini | Combine text, image, audio | “CLIP” (2021), “Flamingo” (2022) |
#
# ---
#
# ### 3. Why Generative AI Is Game‑Changing
#
# | Benefit | Example |
# |---------|---------|
# | **Creativity & Content Creation** | AI‑generated story drafts, marketing copy, music tracks. |
# | **Productivity Boost** | Auto‑summarizing documents, generating code snippets, drafting emails. |
# | **Personalization** | Tailored recommendations, custom avatars, adaptive learning materials. |
# | **Accessibility** | Turning text into speech for visually impaired users, translating in real‑time. |
# | **Prototyping** | Rapid design mock‑ups, concept art for games and films. |
#
# ---
#
# ### 4. Challenges & Ethical Considerations
#
# | Issue | What It Means | Mitigation Strategies |
# |-------|---------------|-----------------------|
# | **Bias & Fairness** | Models can reflect societal biases present in training data. | Diverse training sets, bias audits, post‑processing filters. |
# | **Misinformation** | AI can produce realistic but false text or deepfakes. | Fact‑checking pipelines, watermarking, user education. |
# | **Copyright & Ownership** | Generated content may infringe on existing works. | Copyright‑aware training, licensing agreements, user agreements. |
# | **Privacy** | Models may inadvertently memorize personal data. | Differential privacy, data removal techniques. |
# | **Environmental Impact** | Training large models consumes significant energy. | Efficient architectures, renewable energy sources, model distillation. |
#
# ---
#
# ### 5. A Simple Analogy
#
# - **Traditional AI (e.g., image classifier)**: *“Given this photo, tell me what it is.”*
# - **Generative AI**: *“Imagine a brand‑new photo that looks like it could belong in this dataset.”*
#
# Just like a chef can learn recipes from thousands of dishes and then invent a brand‑new dish, a generative model learns patterns from data and then *creates* something novel.
#
# ---
#
# ### 6. Getting Started with GEN‑AI
#
# | Resource | What You’ll Learn |
# |----------|-------------------|
# | **OpenAI Playground** | Try GPT‑4 or GPT‑3.5 in a web UI. |
# | **Hugging Face Spaces** | Run free demos of Stable Diffusion, GPT‑2, etc. |
# | **Google Colab** | Run notebooks that fine‑tune small models on your own data. |
# | **Fast.ai / Coursera** | Intro courses on deep learning & generative models. |
# | **Open Source Projects** | 🤗 Transformers, diffusers, fairseq. |
#
# ---
#
# ### 7. Quick FAQ
#
# | Question | Answer |
# |----------|--------|
# | **Is GEN‑AI the same as “AI”?** | It’s a subset of AI focused on creation, not just recognition or decision‑making. |
# | **Do I need to be a data scientist?** | No. Many tools let non‑experts experiment via simple interfaces or “prompt engineering.” |
# | **Can it replace human creators?** | It augments creativity; humans still guide, edit, and curate the output. |
# | **How do I keep my data safe?** | Use on‑prem or private cloud deployments; consider federated learning. |
# | **What’s the future?** | More efficient models, stronger safety guarantees, deeper multimodal integration. |
#
# ---
#
# ### 8. Take‑away
#
# - **GEN‑AI** = *AI that can *generate* new content.*
# - It relies on large neural networks trained on massive datasets.
# - It powers a wide range of applications—from writing assistants to art generators.
# - While it offers huge benefits, it also raises important ethical and technical challenges that researchers, companies, and policymakers are actively addressing.
#
# Feel free to dive deeper into any of the sections or ask about specific use cases!
